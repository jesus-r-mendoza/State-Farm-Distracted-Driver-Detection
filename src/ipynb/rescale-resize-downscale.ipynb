# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
from skimage import io
from tqdm import tqdm

# %%
img=cv2.imread('/Users/Juan/Desktop/CS4662/imgs/train/c0/img_34.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap="gray")
plt.show()

# %%
# training path

DATADIR = "/Users/Juan/Desktop/CS4662/imgs/train"
categories= [ 'c0','c1','c2','c3','c4','c5','c6','c7','c8','c9']

# %%
# training_data = []
# def create_td():
#     for category in categories:
#         path  = os.path.join(DATADIR, category)
#         class_num = categories.index(category)
#         for img in os.listdir(path):
#             img_array=cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
#             training_data.append([img_array,class_num])

# %%
# %%time
# create_td()
# print(len(training_data))

# %% [markdown]
# ### method to resize images, made 3 different lists that changed the size of the image in different ways

# %%
rescale_td=[]
resize_td=[]
downscale_td=[]

def create_td():
    for category in tqdm(categories):
        path = os.path.join(DATADIR,category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            img_array=cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
            img_rescale = rescale(img_array, 1.0/4.0, anti_aliasing = False)
            img_resize = resize(img_array, (img_array.shape[0] / 4, img_array.shape[1] / 4),anti_aliasing=True)
            img_downscale = downscale_local_mean(img_array, (4, 3))            
            rescale_td.append([img_rescale,class_num])
            resize_td.append([img_resize,class_num])
            downscale_td.append([img_downscale,class_num])

# %%
##example tqdm
# import time
# list = []
# for i in tqdm(range(100)):
#     time.sleep(1)
#     list.append(i)
# print(list)

# %%
create_td()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#  10%|█         | 1/10 [00:57<08:34, 57.14s/it]
#
#
#  20%|██        | 2/10 [02:16<08:29, 63.67s/it]
#
#
#  30%|███       | 3/10 [04:08<09:08, 78.32s/it]
#
#
#  40%|████      | 4/10 [06:15<09:17, 92.92s/it]
#
#
#  50%|█████     | 5/10 [09:08<09:44, 116.94s/it]
#
#
#  60%|██████    | 6/10 [12:16<09:13, 138.26s/it]
#
#
#  70%|███████   | 7/10 [14:43<07:02, 140.76s/it]
#
#
#  80%|████████  | 8/10 [17:24<04:53, 146.94s/it]
#
#
#  90%|█████████ | 9/10 [20:36<02:40, 160.49s/it]
#
#
# 100%|██████████| 10/10 [23:24<00:00, 162.69s/it]

# %%
print(len(rescale_td))
print(len(resize_td))
print(len(downscale_td))
# Out:
# 22424
# 22424
# 22424
