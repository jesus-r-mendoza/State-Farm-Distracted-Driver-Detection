# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
from skimage import data, color
from skimage.transform import rescale, resize, downscale_local_mean
from skimage import io
from tqdm import tqdm

# %%
img=cv2.imread('/Users/Juan/Desktop/CS4662/imgs/test/img_1.jpg',cv2.IMREAD_GRAYSCALE)
# img=cv2.imread('/Users/hollo/Desktop/DataScience/project/imgs/train/c0/img_34.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img,cmap="gray")
plt.show()

# %%
# training path

DATADIR = "/Users/Juan/Desktop/CS4662/imgs/test"
# DATADIR = "/Users/hollo/Desktop/DataScience/project/imgs/train"

# %%
rescale_td=[]
resize_td=[]
downscale_td=[]

def create_testData():
    path = os.listdir(DATADIR)
    for image in tqdm(path):
        img = os.path.join(DATADIR,image)
        img_array=cv2.imread(img,cv2.IMREAD_GRAYSCALE)
        img_rescale = rescale(img_array, 1.0/4.0, anti_aliasing = False)
        img_resize = resize(img_array, (img_array.shape[0] / 4, img_array.shape[1] / 4),anti_aliasing=True)
        img_downscale = downscale_local_mean(img_array, (4, 3))            
        rescale_td.append(img_rescale)
        resize_td.append(img_resize)
        downscale_td.append(img_downscale)

# %%
create_testData()
# Out:
#   0%|                                                | 0/79726 [00:00<?, ?it/s]C:\Users\Juan\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '
# C:\Users\Juan\Anaconda3\lib\site-packages\skimage\transform\_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
#  58%|██████████████████▋             | 46480/79726 [1:23:38<1:31:41,  6.04it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-7228df696908> in <module>
# ----> 1 create_testData()
#
# <ipython-input-9-889c580a8fb7> in create_testData()
#       8         img = os.path.join(DATADIR,image)
#       9         img_array=cv2.imread(img,cv2.IMREAD_GRAYSCALE)
# ---> 10         img_rescale = rescale(img_array, 1.0/4.0, anti_aliasing = False)
#      11         img_resize = resize(img_array, (img_array.shape[0] / 4, img_array.shape[1] / 4),anti_aliasing=True)
#      12         img_downscale = downscale_local_mean(img_array, (4, 3))
#
# ~\Anaconda3\lib\site-packages\skimage\transform\_warps.py in rescale(image, scale, order, mode, cval, clip, preserve_range, multichannel, anti_aliasing, anti_aliasing_sigma)
#     280                   clip=clip, preserve_range=preserve_range,
#     281                   anti_aliasing=anti_aliasing,
# --> 282                   anti_aliasing_sigma=anti_aliasing_sigma)
#     283
#     284
#
# ~\Anaconda3\lib\site-packages\skimage\transform\_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range, anti_aliasing, anti_aliasing_sigma)
#     167         out = warp(image, tform, output_shape=output_shape, order=order,
#     168                    mode=mode, cval=cval, clip=clip,
# --> 169                    preserve_range=preserve_range)
#     170
#     171     else:  # n-dimensional interpolation
#
# ~\Anaconda3\lib\site-packages\skimage\transform\_warps.py in warp(image, inverse_map, map_args, output_shape, order, mode, cval, clip, preserve_range)
#     798
#     799     """
# --> 800     image = convert_to_float(image, preserve_range)
#     801
#     802     input_shape = np.array(image.shape)
#
# ~\Anaconda3\lib\site-packages\skimage\_shared\utils.py in convert_to_float(image, preserve_range)
#     241         image = image.astype(np.double)
#     242     else:
# --> 243         image = img_as_float(image)
#     244     return image
#     245
#
# ~\Anaconda3\lib\site-packages\skimage\util\dtype.py in img_as_float(image, force_copy)
#     417
#     418     """
# --> 419     return convert(image, np.floating, force_copy)
#     420
#     421
#
# ~\Anaconda3\lib\site-packages\skimage\util\dtype.py in convert(image, dtype, force_copy, uniform)
#     300             # until the computation time
#     301             image = np.multiply(image, 1. / imax_in,
# --> 302                                 dtype=computation_type)
#     303             # DirectX uses this conversion also for signed ints
#     304             # if imin_in:
#
# MemoryError:

# %%
df_rescale = pd.DataFrame(rescale_td)
